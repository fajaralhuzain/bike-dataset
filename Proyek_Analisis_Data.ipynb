# %% [markdown]
# # Proyek Analisis Data: [Bike-sharing-dataset]
# - **Nama:** [Fajar al huzain]
# - **Email:** [fajaralhuzain@gmail.com]
# - **ID Dicoding:** [MC193D5Y1134]

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
import plotly.express as px

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
#Gathering Data
# Load dataset
file_path = "Dashboard/day.csv"
df = pd.read_csv(file_path)

# Display first few rows
print("Initial Data Preview:")
display(df.head())
# Out:
# Initial Data Preview:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %%
# Assessing Data
print("\nDataset Information:")
df.info()

print("\nSummary Statistics:")
print(df.describe())

print("\nChecking for Missing Values:")
print(df.isnull().sum())

print("\nChecking for Duplicates:")
print(df.duplicated().sum())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB
#
# Summary Statistics:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.465233    0.544894    0.183051    0.162961    0.142429    0.077498
# min      0.000000    1.000000    0.059130    0.079070    0.000000    0.022392
# 25%      0.000000    1.000000    0.337083    0.337842    0.520000    0.134950
# 50%      1.000000    1.000000    0.498333    0.486733    0.626667    0.180975
# 75%      1.000000    2.000000    0.655417    0.608602    0.730209    0.233214
# max      1.000000    3.000000    0.861667    0.840896    0.972500    0.507463
#
#             casual   registered          cnt
# count   731.000000   731.000000   731.000000
# mean    848.176471  3656.172367  4504.348837
# std     686.622488  1560.256377  1937.211452
# min       2.000000    20.000000    22.000000
# 25%     315.500000  2497.000000  3152.000000
# 50%     713.000000  3662.000000  4548.000000
# 75%    1096.000000  4776.500000  5956.000000
# max    3410.000000  6946.000000  8714.000000
#
# Checking for Missing Values:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64
#
# Checking for Duplicates:
# 0

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %%
# Cleaning Data
# Convert date column to datetime format
df['dteday'] = pd.to_datetime(df['dteday'])

# Drop duplicate rows if any
df = df.drop_duplicates()

# Handle missing values (if any, though none were found in the assessment)
df = df.dropna()

# Renaming columns for better readability
df.rename(columns={'cnt': 'total_rentals', 'mnth': 'month', 'yr': 'year'}, inplace=True)

# Verifying cleaning steps
print("\nCleaned Data Preview:")
display(df.head())

# Save cleaned dataset
df.to_csv("cleaned_day.csv", index=False)

print("\nData wrangling complete. Cleaned dataset saved as 'cleaned_day.csv'.")
# Out:
# Cleaned Data Preview:
#    instant     dteday  season  year  month  holiday  weekday  workingday  \
# 0        1 2011-01-01       1     0      1        0        6           0
# 1        2 2011-01-02       1     0      1        0        0           0
# 2        3 2011-01-03       1     0      1        0        1           1
# 3        4 2011-01-04       1     0      1        0        2           1
# 4        5 2011-01-05       1     0      1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#    total_rentals
# 0            985
# 1            801
# 2           1349
# 3           1562
# 4           1600
# Data wrangling complete. Cleaned dataset saved as 'cleaned_day.csv'.

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
# Exploratory Data Analysis (EDA)
print("\nExploratory Data Analysis (EDA)")
plt.figure(figsize=(10, 5))
sns.histplot(df['total_rentals'], bins=30, kde=True)
plt.title("Distribution of Total Rentals")
plt.xlabel("Total Rentals")
plt.ylabel("Frequency")
plt.show()
# Out:
# Exploratory Data Analysis (EDA)

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %%
# Visualization & Explanatory Analysis
print("\nVisualization & Explanatory Analysis")
plt.figure(figsize=(12, 6))
sns.boxplot(x='season', y='total_rentals', data=df)
plt.title("Total Rentals by Season")
plt.xlabel("Season")
plt.ylabel("Total Rentals")
plt.show()

plt.figure(figsize=(12, 6))
sns.lineplot(x='dteday', y='total_rentals', data=df)
plt.title("Total Rentals Over Time")
plt.xlabel("Date")
plt.ylabel("Total Rentals")
plt.xticks(rotation=45)
plt.show()
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Heatmap")
plt.show()
# Out:
# Visualization & Explanatory Analysis

# %% [markdown]
# ## Conclusion

# %%
# Kesimpulan
print("\nKesimpulan:")
print("1. Total penyewaan menunjukkan pola musiman, dengan jumlah penyewaan lebih tinggi pada musim tertentu.")
print("2. Distribusi penyewaan sedikit condong, dengan beberapa hari memiliki jumlah penyewaan yang tinggi.")
print("3. Terdapat tren kenaikan jumlah penyewaan seiring waktu.")
print("4. Kondisi cuaca dan musim tertentu tampaknya memengaruhi jumlah penyewaan.")
# Out:
# Kesimpulan:
# 1. Total penyewaan menunjukkan pola musiman, dengan jumlah penyewaan lebih tinggi pada musim tertentu.
# 2. Distribusi penyewaan sedikit condong, dengan beberapa hari memiliki jumlah penyewaan yang tinggi.
# 3. Terdapat tren kenaikan jumlah penyewaan seiring waktu.
# 4. Kondisi cuaca dan musim tertentu tampaknya memengaruhi jumlah penyewaan.
